# %% [markdown]
# # Discover Keywords for each document
#
# ## Overview
#
# This prints out a summary of each document, collected together [here](xx).
#
# As seen in the outputs, for example, for the first document, keywords around security and commissioning are proposed.
#
# And for construction assurance, the focus is on design, construction, safety, contractors and material.
#
# ## Installation
#
# Check installation has been made, as per the [READme](https://github.com/lawrencerowland/Data-Model-for-Project-Frameworks/blob/master/Project-frameworks-by-using-NLP-with-Python-libraries/README.md)
#
# ## Prior steps
# None of the steps 1-3 are needed in order to generate these keywords.
#
# But to generate keywords of new documents, review these steps to see which you require.
#
# ## How-to-use
# xx
#
# ## Import Gensim

# %%
import gensim
from gensim.summarization import keywords
# Out:
# unable to import 'smart_open.gcs', disabling that module

# %% [markdown]
# ## Change Directory to find the portfolio text files

# %%
#hide
import os
directory = '/Users/lawrence/Documents/GitHub/Data-Model-for-Project-Frameworks/Project-frameworks-by-using-NLP-with-Python-libraries/Text-files-as-generated-by-PDF-Miner'
# Change directory location for your particular set-up.

# %%
Keywords_per_document =[]
Keywords_per_document_as_string=""

for filename in os.listdir(directory):
    if filename.endswith('.txt'):
        with open(os.path.join(directory, filename)) as f:
            
            content = f.read()
            
            key_words=(filename+'Summary\n'+keywords(content, ratio=0.007)+'\n')
            
            print ('\nFile',filename)
            print ('Keywords:',key_words)
            
            Keywords_per_document.append(key_words)
            Keywords_per_document_as_string+=(key_words)
    
            f.close()
# Adjust the ratio of keywords to total content size if required. 
#There are also optional input parameters to change lemmatization, word-splitting and stemming.
# Out:
# File Commissioning of security systems and infrastructure cns-tast-gd-4.4 cns-tast-gd-4.4.pdf.txt
# Keywords: Commissioning of security systems and infrastructure cns-tast-gd-4.4 cns-tast-gd-4.4.pdf.txtSummary
# security
# securely
# secure
# commissioning
# commissioned
#
#
# File Construction Assurance ns-tast-gd-076.pdf.txt
# Keywords: Construction Assurance ns-tast-gd-076.pdf.txtSummary
# design
# designer
# designers
# designed
# designs
# designing
# construction
# constructed
# construct
# safety
# contractor
# contractors
# materials
# material
#
#
# File Control of processes involving nuclear matter ns-tast-gd-023.pdf.txt
# Keywords: Control of processes involving nuclear matter ns-tast-gd-023.pdf.txtSummary
# control
# controlled
# controls
# controlling
# safety
# nuclear
#
#
# File Decommissioning ns-tast-gd-026.txt
# Keywords: Decommissioning ns-tast-gd-026.txtSummary
# decommissioning
# decommissioned
# decommission
# safety
# regulation
# regulators
# regulating
# regulations
# regulator
# regulate
# operated
# operations
# operational
# operating
# operation
# operators
# operator
# operates
# appropriate
# appropriately
# appropriateness
# including
# include
# includes
# included
#
#
# File Design Safety Assurance ns-tast-gd-057.pdf.txt
# Keywords: Design Safety Assurance ns-tast-gd-057.pdf.txtSummary
# design
# designs
# designed
# designers
# designated
# designer
# safety
# processes
# process
# requires
# requirements
# required
# requirement
# requiring
# require
#
#
# File Fundamental Principles ns-tast-gd-004.pdf.txt
# Keywords: Fundamental Principles ns-tast-gd-004.pdf.txtSummary
# safety
# saps
# sap
# principles
# principle
#
#
# File Guidance on the Demonstration of ALARP ns-tast-gd-005.pdf.txt
# Keywords: Guidance on the Demonstration of ALARP ns-tast-gd-005.pdf.txtSummary
# risks
# risk
# alarp
# safety
# standards
# standard
# onr
# practicable
# practice
# practicability
# practical
# practices
#
#
# File Management of Radioactive material ns-tast-gd-024.pdf.txt
# Keywords: Management of Radioactive material ns-tast-gd-024.pdf.txtSummary
# waste
# wastes
# regulation
# regulators
# regulations
# regulate
# regulator
# regulates
# regulating
# including
# includes
# include
# management
# managed
# manages
# managing
# managers
# manage
# safety
#
#
# File nuclear construction sites cns-tast-gd-6.6.pdf.txt
# Keywords: nuclear construction sites cns-tast-gd-6.6.pdf.txtSummary
# security
# securely
# secure
# secured
# securing
# sites
# site
# nuclear
#
#
# File Organisational Change ns-tast-gd-048.pdf.txt
# Keywords: Organisational Change ns-tast-gd-048.pdf.txtSummary
# change
# changes
# changed
# onr
# safety
# arrangements
# arrange
#
#
# File oversight of items or services cns-tast-gd-4.3.pdf.txt
# Keywords: oversight of items or services cns-tast-gd-4.3.pdf.txtSummary
# security
# securely
# nuclear
#
#
# File Probabilistic Safety Analysis.pdf.txt
# Keywords: Probabilistic Safety Analysis.pdf.txtSummary
# psas
# psa
# include
# including
# included
# includes
# events
# event
# analysis
# modelling
# model
# models
# modelled
# operated
# operation
# operating
# operational
# operators
# operator
# operate
# operability
# operations
# specific
# specifically
# specification
# specifications
#
#
# File Procedure Design and Administrative Controls.pdf.txt
# Keywords: Procedure Design and Administrative Controls.pdf.txtSummary
# procedure
# procedures
# procedural
# safety
# operated
# operating
# operations
# operator
# operational
# operation
# operators
# operate
#
#
# File Procurement cns-tast-gd-4.1 cns-tast-gd-4.1.pdf.txt
# Keywords: Procurement cns-tast-gd-4.1 cns-tast-gd-4.1.pdf.txtSummary
# security
# securely
# nuclear
# onr
#
#
# File Reliability and resilience of the security system cns-tast-gd-5.1 cns-tast-gd-5.1.pdf.txt
# Keywords: Reliability and resilience of the security system cns-tast-gd-5.1 cns-tast-gd-5.1.pdf.txtSummary
# security
# securely
# secure
# nuclear
#
#
# File Supplier capability cns-tast-gd-4.2.pdf.txt
# Keywords: Supplier capability cns-tast-gd-4.2.pdf.txtSummary
# security
# securely
# nuclear

# %% [markdown]
# ## Save the results as interim file

# %%
directory= "/Users/lawrence/Documents/GitHub/Data-Model-for-Project-Frameworks/Project-frameworks-by-using-NLP-with-Python-libraries/Interim-results/"

# %%
filename="Keyword_per_document"
f=open(directory+filename+".txt","w+")  
f.write(Keywords_per_document_as_string)
f.close()

# %% [markdown]
# # Next
# Progress to Step 5 (creating one single library of all documents) (xx) or return to the main sequence of steps (xx)
